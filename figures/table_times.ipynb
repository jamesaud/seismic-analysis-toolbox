# %%
csv = '/home/audretj/developer-projects/waveforms/notebooks/combine-csv/results-complete.csv'

# %%
import pandas as pd
df = pd.read_csv(csv)

# %%
df
# Out:
#      Unnamed: 0  Amount Correct Local  Amount Correct Noise  \
# 0             0                1035.0                1523.0
# 1             1                1052.0                1506.0
# 2             2                 978.0                1452.0
# 3             3                 904.0                1526.0
# 4             4                 397.0                 754.0
# 5             5                 938.0                1491.0
# 6             6                 701.0                  66.0
# 7             7                 992.0                 542.0
# 8             8                1093.0                1463.0
# 9             9                1103.0                1453.0
# 10           10                1115.0                1313.0
# 11           11                1142.0                1413.0
# 12           12                1024.0                1531.0
# 13           13                1058.0                 986.0
# 14           14                1120.0                1562.0
# ...
