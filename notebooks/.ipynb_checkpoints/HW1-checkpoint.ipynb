# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("http://10.254.144.226/")
t = UTCDateTime("2016-06-15T00:00:00.000")

day = 60 * 60
start, end = t, t + day

bulk = [("TZ", "CES06", "", "HNZ", start, end)]
#for _ in range(5):
#    bulk.append(("TZ", "CES06", "", "HNZ", start, end))
    #start, end = end, end + day

st = client.get_waveforms("TZ", "CES06", "", "HNZ", start, end)
st.plot(type="dayplot")
