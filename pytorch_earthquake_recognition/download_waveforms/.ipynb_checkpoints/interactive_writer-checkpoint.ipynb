# %%
import matplotlib
import argparse
import os
import warnings
from code.config import WAVEFORMS_PATH, SPECTROGRAM_PATH
from code.spectrograms import async_write_spectrograms
from code.waveforms import read_waveforms
from code.filter import filter_waveforms

# %%
WAVEFORMS_PATH = 'waveforms/-20.7771-167.240204'
SPECTROGRAM_PATH = 'spectrograms/test'

local_path = os.path.join(WAVEFORMS_PATH, "local")
local_waveforms = read_waveforms(local_path)

# %%
noise_path = os.path.join(WAVEFORMS_PATH, "noise")
noise_waveforms = read_waveforms(noise_path)

# %%
import copy
wf = copy.deepcopy(local_waveforms[90])

# %%
wf.spectrogram()
# Out:
# [None, None, None]

# %%
local_waves = filter_waveforms([copy.deepcopy(wf)], pre_padding=9, post_padding=11, padding=20)

# %%
local_waves[0].spectrogram()
# Out:
# [None, None, None]

# %%
def write_local():
        print("Writing local")
        local_waveforms = read_waveforms(local_path)
        local_waves = filter_waveforms(local_waveforms,
                                       pre_padding=10,
                                       post_padding=10,
                                       padding=20)
        async_write_spectrograms(local_waves, os.path.join(SPECTROGRAM_PATH, "local"))

def write_noise():
    print("Writing noise")
    noise_waveforms = read_waveforms(noise_path)
    noise_waves = filter_waveforms(noise_waveforms,
                                   pre_padding=10,
                                   post_padding=10,
                                   padding=20)
    async_write_spectrograms(noise_waves, os.path.join(SPECTROGRAM_PATH, "noise"))

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    write_local()
# Out:
# Writing local
# Writing Files...
# <class 'ValueError'>
# Failed to write spectrogram:  noverlap must be less than n
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'AttributeError'>
# Failed to write spectrogram:  'MaskedConstant' object has no attribute '_fill_value'
#
# Wrote Files

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    write_noise()
# Out:
# Writing noise
# Writing Files...
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'ValueError'>
# Failed to write spectrogram:  noverlap must be less than n
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'AttributeError'>
# Failed to write spectrogram:  'MaskedConstant' object has no attribute '_fill_value'
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
# <class 'IndexError'>
# Failed to write spectrogram:  index 1 is out of bounds for axis 0 with size 1
#
# Wrote Files
