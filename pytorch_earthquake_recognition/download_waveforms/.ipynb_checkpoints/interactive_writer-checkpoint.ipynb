# %%
import matplotlib
import argparse
import os
import warnings
from code.config import WAVEFORMS_PATH, SPECTROGRAM_PATH
from code.spectrograms import async_write_spectrograms
from code.waveforms import read_waveforms
from code.filter import filter_waveforms

# %%
WAVEFORMS_PATH = 'waveforms/31.867887--116.664459'
SPECTROGRAM_PATH = 'spectrograms/31.867887--116.664459'

local_path = os.path.join(WAVEFORMS_PATH, "local")
local_waveforms = read_waveforms(local_path)

# %%
import copy
wf = copy.deepcopy(local_waveforms[120])

# %%
wf.plot()

# %%
wf = [wf]

# %%
local_waves = filter_waveforms(wf, pre_padding=8, post_padding=12, padding=20)

# %%
local_waves[0].plot()
