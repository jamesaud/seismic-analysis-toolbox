# %% [markdown]
# ## 1. Locate a Station Near The Event

# %% [markdown]
# ### Global Variable Constants

# %%
from obspy.clients.fdsn import Client
from obspy.core.utcdatetime import UTCDateTime
from types import MappingProxyType

def Day(num):
    return 60*60*24*num

def get_event_info(name):
    """
    Provides a dictionary (MappingProxyType) of information to populate the global variables needed in the file.
    The chosen event is in a seismologically active area. A station is chosen near the event to get data.
    @param name: Can be one of - "Amatrice", "Patitirion"
    @return: ProxyMapType, containing the information about the event.
    """
    info: MappingProxyType = None
    if name == 'Amatrice':
        info = dict(
            Latitude='42.790',
            Longitude='13.150',
            Time="2016-08-24 03:36:32",
            StartTime="2012-08-24",
            EndTime="2018-08-24",
            Client="INGV",
            Name="Amatrice",
            StationRadius=.2,
            LocalEventRadius=1
        )

    elif name == 'Oklahoma':
        info = dict(
            Latitude='37.081',
            Longitude='-97.309',
            Time="2018-5-15 20:14:49",
            StartTime="2015-10-15",
            EndTime="2017-10-15",
            Client="IRIS",
            Name="Oklahoma",
            StationRadius=1,
            LocalEventRadius=1
        )
    
    elif name == "SouthAmerica":
        info = dict(
            Latitude='-25.3',
            Longitude='-71',
            Time="2018-02-20 23:18:32",
            StartTime="2013-10-15",
            EndTime="2018-01-15",
            Client="IRIS",
            Name="SouthAmerica",
            StationRadius=3,
            LocalEventRadius=1
        )
    
    elif name == "California":
        info = dict(
            Latitude='33.557',
            Longitude='-115.888',
            Time="2018-02-20 23:18:32",
            StartTime="2016-10-15",
            EndTime="2018-01-15",
            Client="IRIS",
            Name="California",
            StationRadius=1,
            LocalEventRadius=1
        )
    
    elif name == 'Alaska':
        info = dict(
            Latitude='63.134',
            Longitude='-151.115',
            Time="2018-02-20 23:18:32",
            StartTime="2016-01-01",
            EndTime="2018-02-26",
            Client="IRIS",
            Network="NP",
            Station="8040",
            Name="Alaska",
            StationRadius=6,
            LocalEventRadius=1
        )
    
    if info: 
        return MappingProxyType(info)
    raise ValueError(f"Name '{name}' not found")

# %%
# CHANGE THIS VARIABLE TO CHANGE EVERYTHING IN THE FILE
event_name = 'Alaska'

# %%
# Retrieving the quake information            
event = get_event_info(event_name)   # dict containing the information to populate the variables

# Constants
LATITUDE = event['Latitude']                # Latitude of Event
LONGITUDE = event['Longitude']              # Longitude of Event
STARTTIME = UTCDateTime(event['StartTime']) # Starttime of Data Collection
ENDTIME = UTCDateTime(event['EndTime'])     # Endtime of Data Collection
CLIENT_NAME = event['Client']               # Client to retrieve event from
NAME = event['Name'] + 'Quakes'             # Folder name to write spectrograms to

STATION_MAX_RADIUS = event['StationRadius'] # Pick as station within this distance of the event
MAX_RADIUS = event['LocalEventRadius']      # How far local events can be from the station
NONLOCAL_MIN_RADIUS = 6                     # Min Radius for Nonlocal Events
NUM_EVENTS = 2000                            # How many events to retrieve and write                     # Event time window duration
NUM_NOISE_EVENTS = NUM_EVENTS
DURATION = 15          

NETWORK = event.get('Network')
STATION = event.get('Station')

# Filtering Constants for the Spectrograms
MIN_FREQ = 3
MAX_FREQ = 30

# %% [markdown]
# ### Get Nearest Station

# %%
from obspy.core.inventory import Inventory, Station, Network

# Types
inventory: Inventory
network: Network
station: Station
    

# Code
client = Client(CLIENT_NAME)

inventory = client.get_stations(startbefore=STARTTIME, 
                               endafter=ENDTIME,
                               latitude=LATITUDE,
                               longitude=LONGITUDE,
                               maxradius=STATION_MAX_RADIUS
                              )

network = (inventory.select(NETWORK) if NETWORK else inventory)[0]

station = (network.select(STATION) if STATION else network)[0]

# %%
# Optional, Visualize the Station
print(station)
# inventory.plot(projection='local')
# inventory.plot()
# Out:
# Station 8040 (AK:Anchorage;R B Atwood Bld)
# 	Station Code: 8040
# 	Channel Count: 0/106 (Selected/Total)
# 	2003-09-05T18:00:00.000000Z - 2599-12-31T23:59:59.000000Z
# 	Access: open
# 	Latitude: 61.21, Longitude: -149.89, Elevation: -17.4 m
# 	Available Channels:

# %%
# Verify that waveform FDSN works, so you don't waste time getting to the bottom 
def get_channel_names(stream):
    """ Returns a list of names of each component, in the order they appear in the stream """
    return [trace.stats.channel for trace in stream]

def verify_fsdn(network, station):
    """ Tests a call to the server """
    client = Client(CLIENT_NAME)
    client.get_waveforms(network.code, station.code, "*", "HN*", STARTTIME, STARTTIME + DURATION)
    return True

def get_valid_stations(inventory):
    """ Attempts to get waveforms from a station, with the veriy_fsdn function. Returns valid stations """
    valid = []
    for network in inventory:
        for station in network:
            try:
                verify_fsdn(network, station)
            except Exception:
                print("Failed station:", station.code)
            else:
                print("Succeeded station:", station.code)
                valid.append(station)
    return valid
                
assert verify_fsdn(network, station)

# %%
print(inventory)
# Out:
# Inventory created at 2018-02-28T08:40:43.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.32
# 		    http://service.iris.edu/fdsnws/station/1/query?startbefore=2016-01-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (15):
# 			AK, AT, AV, CN, GD, II, IM, IU, NP, PN, PP, SY, TA, US, XV
# 		Stations (576):
# 			AK.BAGL (Bagley Icefield, AK, USA)
# 			AK.BAL (Baldy Mountain, AK, USA)
# 			AK.BARK (Barkley Ridge, AK, USA)
# 			AK.BARN (Barnard Glacier, AK, USA)
# 			AK.BERG (Berg Lake, AK, USA)
# 			AK.BGLC (Bering Glacier BLM Camp, AK, USA)
# 			AK.BMR (Bremner River, AK, USA)
# 			AK.BPAW (Bear Paw Mountain, AK, USA)
# 			AK.BRLK (Bradley Lake, AK, USA)
# 			AK.BRSE (Bradley Lake South, AK, USA)
# 			AK.BWN (Browne, AK, USA)
# 			AK.CAPN (Captain Cook Nikiski, AK, USA)
# 			AK.CAST (Castle Rocks, AK, USA)
# 			AK.CCB (Clear Creek Butte, AK, USA)
# 			AK.CHUM (Lake Minchumina, AK, USA)
# 			AK.CNP (China Poot, AK, USA)
# 			AK.CRQ (Cirque, AK, USA)
# 			AK.CTG (Chitna Glacier, AK, USA)
# 			AK.CUT (Chulitna, AK, USA)
# 			AK.CYK (Cape Yakataga, AK, USA)
# 			AK.DHY (Denali Highway, AK, USA)
# 			AK.DIV (Divide Microwave, AK, USA)
# 			AK.DOT (Dot Lake, AK, USA)
# 			AK.EYAK (Cordova Ski Area, AK, USA)
# 			AK.FID (Fidalgo, AK, USA)
# 			AK.FIRE (Fire Island, AK, USA)
# 			AK.FYU (Fort Yukon, AK, USA)
# 			AK.GCSA (Galena City School, AK, USA)
# 			AK.GHO (Gloryhole, AK, USA)
# 			AK.GIB (Geophysical Institute, Fairbanks, AK)
# 			AK.GLB (Gilahina Butte, AK, USA)
# 			AK.GLI (Glacier Island, AK, USA)
# 			AK.GOAT (Goat Mountain, AK, USA)
# 			AK.GRIN (Grindle Hills, AK, USA)
# 			AK.GRNC (Granite Creek, AK, USA)
# 			AK.HDA (Harding Lake, AK, USA)
# 			AK.HIN (Hinchinbrook, AK, USA)
# 			AK.HMT (Hamilton, AK, USA)
# 			AK.HOM (Homer Trailer, AK, USA)
# 			AK.ISLE (Juniper Island, AK, USA)
# 			AK.KAI (Kayak Island, AK, USA)
# 			AK.KHIT (Khitrov Hills, AK, USA)
# 			AK.KIAG (Kiagna River, AK, USA)
# 			AK.KLU (Klutina Pass, AK, USA)
# 			AK.KNK (Knik Glacier, AK, USA)
# 			AK.KTH (Kantishna Hills, AK, USA)
# 			AK.LOGN (Logan Glacier, AK, USA)
# 			AK.MCAR (McCarthy VSAT, AK, USA)
# 			AK.MCK (McKinley Park, AK, USA)
# 			AK.MDM (Murphy Dome, AK, USA)
# 			AK.MESA (Mesa, AK, USA)
# 			AK.MLY (Manley Hot Springs, AK, USA)
# 			AK.NEA2 (Nenana, AK, USA)
# 			AK.NICH (Nichawak Mountain, AK, USA)
# 			AK.PAX (Paxson, AK, USA)
# 			AK.PIN (Pinnacle, AK, USA)
# 			AK.PPD (Porcupine Dome, AK, USA)
# 			AK.PPLA (Purkeypile, AK, USA)
# 			AK.PTPK (Patty Peak Repeater, AK, USA)
# 			AK.PWL (Port Wells, AK, USA)
# 			AK.RAG (Ragged Mountain, AK, USA)
# 			AK.RC01 (Rabbit Creek, AK, USA)
# 			AK.RIDG (Independent Ridge, AK, USA)
# 			AK.RKAV (Rock Avalanche, AK, USA)
# 			AK.RND (Reindeer, AK, USA)
# 			AK.SAMH (Samovar Hills, AK, USA)
# 			AK.SAW (Sawmill, AK, USA)
# 			AK.SCM (Sheep Mountain, AK, USA)
# 			AK.SCRK (Sand Creek, AK, USA)
# 			AK.SGA (Sherman Glacier, AK, USA)
# 			AK.SKN (Skwentna, AK, USA)
# 			AK.SLK (Skilak Lake, AK, USA)
# 			AK.SSN (Susitna, AK, USA)
# 			AK.SSP (Sunshine Point, AK, USA)
# 			AK.SUCK (Suckling Hills, AK, USA)
# 			AK.SWD (Seward, AK, USA)
# 			AK.TABL (Table Mountain, AK, USA)
# 			AK.TAPE (Goshawk Ln, Fairbanks, AK)
# 			AK.TGL (Tana Glacier, AK, USA)
# 			AK.VRDI (Verde Repeater, AK, USA)
# 			AK.WAT1 (Susitna Watana 1, AK, USA)
# 			AK.WAT6 (Susitna Watana 6, AK, USA)
# 			AK.WAT7 (Susitna Watana 7, AK, USA)
# 			AK.WAX (Waxell Ridge, AK, USA)
# 			AK.WRH (Wood River Hill, AK, USA)
# 			AK.YAH (Yahtse, AK, USA)
# 			AT.MENT (Mentasta, Alaska)
# 			AT.MID (Middleton Island, Alaska)
# 			AT.PMR (Palmer, Alaska)
# 			AT.SVW2 (Sparrevohn, Alaska)
# 			AT.TTA (Tatalina, Alaska)
# 			AV.AU22 (Augustine Mound, Augustine Volcano, Alaska)
# 			AV.AUCH (Augustine Cone H, Augustine Volcano, Alaska)
# 			AV.AUE (Augustine East, Cook Inlet, Alaska)
# 			AV.AUH (Dome H, Augustine Volcano, Alaska)
# 			AV.AUI (Augustine Island, Cook Inlet, Alaska)
# 			AV.AUJA (Augustine Junction, Augustine Volcano, Alaska)
# 			AV.AUJK (Augustine Jurgen Kienle, Cook Inlet, Alaska)
# 			AV.AUL (Lava Flow, Augustine Volcano, Alaska)
# 			AV.AUNW (Augustine Northwest, Augustine Volcano, Alaska)
# 			AV.AUP (Augustine Pinnacle, Cook Inlet, Alaska)
# 			AV.AUQ (Augustine Qik'rtamen, Augustine Volcano, Alaska)
# 			AV.AUSB (Augustine South Buttress, Augustine Volcano, Alaska)
# 			AV.AUSS (Augustine Summit Station, Augustine Volcano, Alaska)
# 			AV.AUW (Augustine West, Cook Inlet, Alaska)
# 			AV.AUWS (Augustine Summit Station, Augustine Volcano, Alaska)
# 			AV.BGL (Barrier Glacier, Mount Spurr, Alaska)
# 			AV.BGM (Big Mountain, Regional Station, Alaska)
# 			AV.BGR (Barrier Glacier Two, regional station, Alaska)
# 			AV.BKG (Blockade Glacier, Mount Spurr, Alaska)
# 			AV.CDD (Cape Douglas, Fourpeaked, Alaska)
# 			AV.CGL (Capps Glacier, Mt. Spurr, Alaska)
# 			AV.CKL (Chakachamna Lake, Mount Spurr, Alaska)
# 			AV.CKN (Chakachatna North, Mt. Spurr, Alaska)
# 			AV.CKT (Bend, Mt. Spurr, Alaska)
# 			AV.CNTC (Contact Creek, Katmai, Alaska)
# 			AV.CP2 (Crater Peak 2, Mt. Spurr, Alaska)
# 			AV.CRP (Crater Peak, Mount Spurr, Alaska)
# 			AV.DFR (Drift River, Redoubt, Alaska)
# 			AV.FONW (Fourpeaked Northwest, Fourpeaked, Alaska)
# 			AV.FOPK (Fourpeaked Mountain, Fourpeaked, Alaska)
# 			AV.FOSS (Fourpeaked Summit, Fourpeaked, Alaska)
# 			AV.ILI (Iliamna Volcano, Alaska)
# 			AV.ILS (Iliamna South, Iliamna Volcano, Alaska)
# 			AV.ILSW (Iliamna Southwest, Iliamna Volcano, Alaska)
# 			AV.ILW (Iliamna West, Iliamna Volcano, Alaska)
# 			AV.IVE (Iliamna Volcano East, Cook Inlet, Alaska)
# 			AV.IVS (Iliamna Volcano Summit, Iliamna Volcano, Alaska)
# 			AV.KAIC (Katmai Ikaluik Glacier, Alaska)
# 			AV.MMN (McNeil River, Regional Station, Alaska)
# 			AV.NCG (North Capps Glacier, Mount Spurr, Alaska)
# 			AV.NCT (North Crescent, Redoubt Volcano, Alaska)
# 			AV.OPT (Oil Point, Regional Station, Alaska)
# 			AV.PDB (Pedro Bay, Regional Station, Alaska)
# 			AV.RDDF (Drift River Broadband, Redoubt Volcano, Alaska)
# 			AV.RDDR (Drift River, Redoubt Volcano, Alaska)
# 			AV.RDJH (Redoubt, Jurgen's Hut, Redoubt Alaska)
# 			AV.RDN (Redoubt North, Redoubt, Alaska)
# 			AV.RDSO (Redoubt South, Redoubt Volcano, Alaska)
# 			AV.RDT (Redoubt, Alaska)
# 			AV.RDWB (Redoubt, Jurgen's Hut, Redoubt Alaska)
# 			AV.RED (Redoubt Volcano, Redoubt Volcano, Alaska)
# 			AV.REF (Redoubt East Flank, Redoubt Volcano, Alaska)
# 			AV.RSO (Redoubt South, Redoubt Volcano, Alaska)
# 			AV.SPBG (Barrier Glacier, Mount Spurr, Alaska)
# 			AV.SPCG (Capps Glacier, Mount Spurr, Alaska)
# 			AV.SPCN (Ckakachatna North Broadband, Mount Spurr, Alaska)
# 			AV.SPCR (Ckakachatna River, Mount Spurr, Alaska)
# 			AV.SPNN (North Nagishlamina, Mount Spurr, Alaska)
# 			AV.SPU (Mount Spurr, Mount Spurr, Alaska)
# 			AV.SPWE (Spurr West, Mount Spurr, Alaska)
# 			AV.STLK (Strandline Lake, Regional Station, Alaska)
# 			AV.SYI (Shuyak Island, Alaska)
# 			AV.WANC (Wrangell North Crater,Mount Wrangell, Alaska)
# 			CN.BVCY (Beaver Creek, YT, CA)
# 			CN.YUK1 (Sand Pete Hill, YT, CA)
# 			CN.YUK2 (White River, YT, CA)
# 			CN.YUK3 (Moose Creek, YT, CA)
# 			CN.YUK8 (Steele Glacier, YT, CA)
# 			GD.FAIR (Gilmore Creek Observatory, Alaska, USA)
# 			GD.TSEA (The Surveyors Ex, Anchorage, Alaska, USA)
# 			II.KDAK (Kodiak Island, Alaska, USA)
# 			IM.BC01 (Beaver Creek Array Site 1, Alaska, U.S.A.)
# 			IM.BC02 (Beaver Creek Array Site 2, Alaska, U.S.A.)
# 			IM.BC03 (Beaver Creek Array Site 3, Alaska, U.S.A.)
# 			IM.BC04 (Beaver Creek Array Site 4, Alaska, U.S.A.)
# 			IM.BC05 (Beaver Creek Array Site 5, Alaska, U.S.A.)
# 			IM.BM01 (Burnt Mountain Array Site 1, Alaska, U.S.A.)
# 			IM.BM02 (Burnt Mountain Array Site 2, Alaska, U.S.A.)
# 			IM.BM03 (Burnt Mountain Array Site 3, Alaska, U.S.A.)
# 			IM.BM04 (Burnt Mountain Array Site 4, Alaska, U.S.A.)
# 			IM.BM05 (Burnt Mountain Array Site 5, Alaska, U.S.A.)
# 			IM.I53H7 (Fairbanks Infrasound Array, Site H7, Fairbanks, Alaska, USA)
# 			IM.IL01 (ILAR Array, Eilson, AK, USA)
# 			IM.IL02 (ILAR Array, Eilson, AK, USA)
# 			IM.IL03 (Indian Mountain Array Site 3, Eilson, AK, USA)
# 			IM.IL04 (ILAR Array, Eilson, AK, USA)
# 			IM.IL05 (ILAR Array, Eilson, AK, USA)
# 			IM.IL06 (ILAR Array, Eilson, AK, USA)
# 			IM.IL07 (ILAR Array, Eilson, AK, USA)
# 			IM.IL08 (ILAR Array, Eilson, AK, USA)
# 			IM.IL09 (ILAR Array, Eilson, AK, USA)
# 			IM.IL10 (ILAR Array, Eilson, AK, USA)
# 			IM.IL11 (ILAR Array, Eilson, AK, USA)
# 			IM.IL12 (ILAR Array, Eilson, AK, USA)
# 			IM.IL13 (ILAR Array, Eilson, AK, USA)
# 			IM.IL14 (ILAR Array, Eilson, AK, USA)
# 			IM.IL15 (ILAR Array, Eilson, AK, USA)
# 			IM.IL16 (ILAR Array, Eilson, AK, USA)
# 			IM.IL17 (ILAR Array, Eilson, AK, USA)
# 			IM.IL18 (ILAR Array, Eilson, AK, USA)
# 			IM.IL19 (ILAR Array, Eilson, AK, USA)
# 			IM.IL31 (ILAR Array, Eilson, AK, USA)
# 			IM.ILAR (ILAR Array Beam, Eilson, AK, USA)
# 			IM.IM01 (Indian Mountain Array Site 1, Alaska, U.S.A.)
# 			IM.IM02 (Indian Mountain Array Site 2, Alaska, U.S.A.)
# 			IM.IM03 (Indian Mountain Array Site 3, Alaska, U.S.A.)
# 			IM.IM04 (Indian Mountain Array Site 4, Alaska, U.S.A.)
# 			IM.IM05 (Indian Mountain Array Site 5, Alaska, U.S.A.)
# 			IU.COLA (College Outpost, Alaska, USA)
# 			NP.2704 (AK:Anchorage;Old Fed Bld)
# 			NP.2716 (AK:Anchorage;Hilton Hotel)
# 			NP.2738 (AK:Cantwell;ADOT Maint Sta)
# 			NP.8007 (AK:Anchorage;Intl Arpt)
# 			NP.8011 (AK:Anch;Russian Jack Spr St Pk)
# 			NP.8019 (AK:Eagle River;Alaska Geol Mat)
# 			NP.8021 (AK:Anchorage;Klatt Elem Sch)
# 			NP.8025 (AK:Anchorage;BS Lutheran Ch)
# 			NP.8026 (AK:Anchorage;Baptist Ch Christ)
# 			NP.8027 (AK:Anchorage;St Fish&Game)
# 			NP.8028 (AK:Anchorage;Coll Gate Elem)
# 			NP.8029 (AK:Anchorage;Tudor Elem Sch)
# 			NP.8030 (AK:Anchorage;Police HQ)
# 			NP.8035 (AK:Kodiak;Chiniak Sch)
# 			NP.8036 (AK:Anchorage;DOI OAS)
# 			NP.8037 (AK:Anchorage;NOAA Weather Fac)
# 			NP.8038 (AK:Anchorage;FS 01 (Central))
# 			NP.8039 (AK:Anchorage;FS 07 (new))
# 			NP.8040 (AK:Anchorage;R B Atwood Bld)
# 			NP.8042 (AK:Anchorage;Frontier Bld)
# 			NP.8043 (AK:Anchorage;Port Access Br)
# 			NP.8045 (AK:Anchorage;VAMC)
# 			NP.8046 (AK:Anchorage;VAMC  FF)
# 			NP.8047 (AK:Anchorage;USGS ESC)
# 			NP.8049 (AK:Kodiak;Fire Dept HQ)
# 			NP.8050 (AK:Kodiak Is;USCG AS Admin Bld)
# 			NP.8051 (AK:Kodiak Is;USCG AS Hanger 1)
# 			NP.8052 (6th avenue, Seward, AK)
# 			NP.ABBK (Woodbourne Dr, Anchorage, AK)
# 			NP.AHOU (City Hall, Houston, AK)
# 			NP.ALUK (Akula Dr, Anchorage, AK)
# 			NP.AMJG (Sams Drive, Wasilla, AK)
# 			NP.ARTY (Chugach Park Dr, Peters Creek, AK)
# 			NP.AZEM (Trapline Dr, Anchorage, AK)
# 			NP.DPA1 (Alaska Delaney Park Array)
# 			NP.DPA2 (Alaska Delaney Park Array)
# 			NP.DPA3 (Alaska Delaney Park Array)
# 			NP.DPA4 (Alaska Delaney Park Array)
# 			PN.CHSA (-)
# 			PN.GCSA (Galena City Schools, Galena, AK, USA)
# 			PN.NHSA (Nikolaevsk School, Nikolaevsk, AK, USA)
# 			PN.PPGRL (David Louis Memorial School, Grayling, AK, USA)
# 			PN.PPSBE (Susan B. English, Seldovia, AK, USA)
# 			PN.SBEA (-)
# 			PP.GCSA (Galena City School)
# 			SY.ACH (ACH synthetic)
# 			SY.ALC2 (ALC2 synthetic)
# 			SY.ALC3 (ALC3 synthetic)
# 			SY.ANCK (ANCK synthetic)
# 			SY.AU22 (AU22 synthetic)
# 			SY.AUCH (AUCH synthetic)
# 			SY.AUJA (AUJA synthetic)
# 			SY.AUL (AUL synthetic)
# 			SY.AUQ (AUQ synthetic)
# 			SY.AUSB (AUSB synthetic)
# 			SY.AUSS (AUSS synthetic)
# 			SY.AUWS (AUWS synthetic)
# 			SY.BAGL (BAGL synthetic)
# 			SY.BAL (BAL synthetic)
# 			SY.BARK (BARK synthetic)
# 			SY.BARN (BARN synthetic)
# 			SY.BERG (BERG synthetic)
# 			SY.BGLC (BGLC synthetic)
# 			SY.BMR (BMR synthetic)
# 			SY.BPAW (BPAW synthetic)
# 			SY.BRLK (BRLK synthetic)
# 			SY.BRSE (BRSE synthetic)
# 			SY.BWN (BWN synthetic)
# 			SY.CAPN (CAPN synthetic)
# 			SY.CAST (CAST synthetic)
# 			SY.CCB (CCB synthetic)
# 			SY.CHSA (CHSA synthetic)
# 			SY.CHUM (CHUM synthetic)
# 			SY.CNP (CNP synthetic)
# 			SY.COL (COL synthetic)
# 			SY.COLA (COLA synthetic)
# 			SY.COLD (COLD synthetic)
# 			SY.CRQ (CRQ synthetic)
# 			SY.CTG (CTG synthetic)
# 			SY.CUT (CUT synthetic)
# 			SY.CYK (CYK synthetic)
# 			SY.D22K (D22K synthetic)
# 			SY.D23K (D23K synthetic)
# 			SY.DAWY (DAWY synthetic)
# 			SY.DDM (DDM synthetic)
# 			SY.DH34 (DH34 synthetic)
# 			SY.DH97 (DH97 synthetic)
# 			SY.DHY (DHY synthetic)
# 			SY.DIV (DIV synthetic)
# 			SY.DOT (DOT synthetic)
# 			SY.E17K (E17K synthetic)
# 			SY.E18K (E18K synthetic)
# 			SY.E19K (E19K synthetic)
# 			SY.E20K (E20K synthetic)
# 			SY.E21K (E21K synthetic)
# 			SY.E22K (E22K synthetic)
# 			SY.E23K (E23K synthetic)
# 			SY.E24K (E24K synthetic)
# 			SY.E25K (E25K synthetic)
# 			SY.EGAK (EGAK synthetic)
# 			SY.EYAK (EYAK synthetic)
# 			SY.F17K (F17K synthetic)
# 			SY.F18K (F18K synthetic)
# 			SY.F19K (F19K synthetic)
# 			SY.F20K (F20K synthetic)
# 			SY.F21K (F21K synthetic)
# 			SY.F22K (F22K synthetic)
# 			SY.F24K (F24K synthetic)
# 			SY.F25K (F25K synthetic)
# 			SY.F26K (F26K synthetic)
# 			SY.FAIR (FAIR synthetic)
# 			SY.FIB (FIB synthetic)
# 			SY.FID (FID synthetic)
# 			SY.FIRE (FIRE synthetic)
# 			SY.FYU (FYU synthetic)
# 			SY.G16K (G16K synthetic)
# 			SY.G17K (G17K synthetic)
# 			SY.G18K (G18K synthetic)
# 			SY.G19K (G19K synthetic)
# 			SY.G21K (G21K synthetic)
# 			SY.G22K (G22K synthetic)
# 			SY.G23K (G23K synthetic)
# 			SY.G24K (G24K synthetic)
# 			SY.G25K (G25K synthetic)
# 			SY.G26K (G26K synthetic)
# 			SY.G27K (G27K synthetic)
# 			SY.GCSA (GCSA synthetic)
# 			SY.GHO (GHO synthetic)
# 			SY.GLB (GLB synthetic)
# 			SY.GLI (GLI synthetic)
# 			SY.GLM (GLM synthetic)
# 			SY.GOAT (GOAT synthetic)
# 			SY.GRIN (GRIN synthetic)
# 			SY.GRNC (GRNC synthetic)
# 			SY.H16K (H16K synthetic)
# 			SY.H17K (H17K synthetic)
# 			SY.H18K (H18K synthetic)
# 			SY.H19K (H19K synthetic)
# 			SY.H20K (H20K synthetic)
# 			SY.H21K (H21K synthetic)
# 			SY.H22K (H22K synthetic)
# 			SY.H23K (H23K synthetic)
# 			SY.H24K (H24K synthetic)
# 			SY.H25K (H25K synthetic)
# 			SY.H25L (H25L synthetic)
# 			SY.H27K (H27K synthetic)
# 			SY.HARP (HARP synthetic)
# 			SY.HDA (HDA synthetic)
# 			SY.HIN (HIN synthetic)
# 			SY.HMT (HMT synthetic)
# 			SY.HOM (HOM synthetic)
# 			SY.I17K (I17K synthetic)
# 			SY.I20K (I20K synthetic)
# 			SY.I21K (I21K synthetic)
# 			SY.I23K (I23K synthetic)
# 			SY.I26K (I26K synthetic)
# 			SY.I27K (I27K synthetic)
# 			SY.I28M (I28M synthetic)
# 			SY.I29M (I29M synthetic)
# 			SY.IL31 (IL31 synthetic)
# 			SY.ILS (ILS synthetic)
# 			SY.ILSW (ILSW synthetic)
# 			SY.ILW (ILW synthetic)
# 			SY.ISLE (ISLE synthetic)
# 			SY.IVE (IVE synthetic)
# 			SY.J14K (J14K synthetic)
# 			SY.J16K (J16K synthetic)
# 			SY.J17K (J17K synthetic)
# 			SY.J18K (J18K synthetic)
# 			SY.J19K (J19K synthetic)
# 			SY.J20K (J20K synthetic)
# 			SY.J25K (J25K synthetic)
# 			SY.J26K (J26K synthetic)
# 			SY.J26L (J26L synthetic)
# 			SY.J29M (J29M synthetic)
# 			SY.J29N (J29N synthetic)
# 			SY.K15K (K15K synthetic)
# 			SY.K17K (K17K synthetic)
# 			SY.K20K (K20K synthetic)
# 			SY.K24K (K24K synthetic)
# 			SY.K27K (K27K synthetic)
# 			SY.KABU (KABU synthetic)
# 			SY.KAHG (KAHG synthetic)
# 			SY.KAI (KAI synthetic)
# 			SY.KAKN (KAKN synthetic)
# 			SY.KDAK (KDAK synthetic)
# 			SY.KHIT (KHIT synthetic)
# 			SY.KIAG (KIAG synthetic)
# 			SY.KLU (KLU synthetic)
# 			SY.KNK (KNK synthetic)
# 			SY.KTH (KTH synthetic)
# 			SY.KULT (KULT synthetic)
# 			SY.L14K (L14K synthetic)
# 			SY.L15K (L15K synthetic)
# 			SY.L16K (L16K synthetic)
# 			SY.L17K (L17K synthetic)
# 			SY.L18K (L18K synthetic)
# 			SY.L19K (L19K synthetic)
# 			SY.L20K (L20K synthetic)
# 			SY.L26K (L26K synthetic)
# 			SY.L27K (L27K synthetic)
# 			SY.L29M (L29M synthetic)
# 			SY.LOGN (LOGN synthetic)
# 			SY.M110 (M110 synthetic)
# 			SY.M14K (M14K synthetic)
# 			SY.M15K (M15K synthetic)
# 			SY.M16K (M16K synthetic)
# 			SY.M17K (M17K synthetic)
# 			SY.M18K (M18K synthetic)
# 			SY.M19K (M19K synthetic)
# 			SY.M20K (M20K synthetic)
# 			SY.M22K (M22K synthetic)
# 			SY.M23K (M23K synthetic)
# 			SY.M24K (M24K synthetic)
# 			SY.M26K (M26K synthetic)
# 			SY.M27K (M27K synthetic)
# 			SY.M29M (M29M synthetic)
# 			SY.MCAR (MCAR synthetic)
# 			SY.MCK (MCK synthetic)
# 			SY.MDM (MDM synthetic)
# 			SY.MEN1 (MEN1 synthetic)
# 			SY.MENT (MENT synthetic)
# 			SY.MESA (MESA synthetic)
# 			SY.MID (MID synthetic)
# 			SY.MLR (MLR synthetic)
# 			SY.MLY (MLY synthetic)
# 			SY.N14K (N14K synthetic)
# 			SY.N15K (N15K synthetic)
# 			SY.N16K (N16K synthetic)
# 			SY.N17K (N17K synthetic)
# 			SY.N18K (N18K synthetic)
# 			SY.N19K (N19K synthetic)
# 			SY.N20K (N20K synthetic)
# 			SY.N25K (N25K synthetic)
# 			SY.NCT (NCT synthetic)
# 			SY.NEA (NEA synthetic)
# 			SY.NEA2 (NEA2 synthetic)
# 			SY.NEB1 (NEB1 synthetic)
# 			SY.NHSA (NHSA synthetic)
# 			SY.NICH (NICH synthetic)
# 			SY.NKA (NKA synthetic)
# 			SY.NTW3 (NTW3 synthetic)
# 			SY.NTW4 (NTW4 synthetic)
# 			SY.O15K (O15K synthetic)
# 			SY.O16K (O16K synthetic)
# 			SY.O17K (O17K synthetic)
# 			SY.O18K (O18K synthetic)
# 			SY.O19K (O19K synthetic)
# 			SY.O20K (O20K synthetic)
# 			SY.O22K (O22K synthetic)
# 			SY.O28M (O28M synthetic)
# 			SY.P16K (P16K synthetic)
# 			SY.P17K (P17K synthetic)
# 			SY.P18K (P18K synthetic)
# 			SY.P23K (P23K synthetic)
# 			SY.PAX (PAX synthetic)
# 			SY.PIN (PIN synthetic)
# 			SY.PMR (PMR synthetic)
# 			SY.POKR (POKR synthetic)
# 			SY.PPD (PPD synthetic)
# 			SY.PPGRL (PPGRL synthetic)
# 			SY.PPLA (PPLA synthetic)
# 			SY.PPSBE (PPSBE synthetic)
# 			SY.PTPK (PTPK synthetic)
# 			SY.PWL (PWL synthetic)
# 			SY.Q16K (Q16K synthetic)
# 			SY.Q17K (Q17K synthetic)
# 			SY.Q19K (Q19K synthetic)
# 			SY.Q20K (Q20K synthetic)
# 			SY.Q23K (Q23K synthetic)
# 			SY.R18K (R18K synthetic)
# 			SY.RAG (RAG synthetic)
# 			SY.RC01 (RC01 synthetic)
# 			SY.RDDF (RDDF synthetic)
# 			SY.RDJH (RDJH synthetic)
# 			SY.RDSO (RDSO synthetic)
# 			SY.RDT (RDT synthetic)
# 			SY.RDW (RDW synthetic)
# 			SY.RDWB (RDWB synthetic)
# 			SY.RED (RED synthetic)
# 			SY.RIDG (RIDG synthetic)
# 			SY.RKAV (RKAV synthetic)
# 			SY.RND (RND synthetic)
# 			SY.SAMH (SAMH synthetic)
# 			SY.SAW (SAW synthetic)
# 			SY.SBEA (SBEA synthetic)
# 			SY.SCM (SCM synthetic)
# 			SY.SCRK (SCRK synthetic)
# 			SY.SGA (SGA synthetic)
# 			SY.SKN (SKN synthetic)
# 			SY.SLK (SLK synthetic)
# 			SY.SPBG (SPBG synthetic)
# 			SY.SPCG (SPCG synthetic)
# 			SY.SPCN (SPCN synthetic)
# 			SY.SPCP (SPCP synthetic)
# 			SY.SPCR (SPCR synthetic)
# 			SY.SPNN (SPNN synthetic)
# 			SY.SPU (SPU synthetic)
# 			SY.SSN (SSN synthetic)
# 			SY.SSP (SSP synthetic)
# 			SY.STLK (STLK synthetic)
# 			SY.SUCK (SUCK synthetic)
# 			SY.SVW2 (SVW2 synthetic)
# 			SY.SWD (SWD synthetic)
# 			SY.TABL (TABL synthetic)
# 			SY.TCOL (TCOL synthetic)
# 			SY.TGL (TGL synthetic)
# 			SY.THY (THY synthetic)
# 			SY.TOK3 (TOK3 synthetic)
# 			SY.TOLK (TOLK synthetic)
# 			SY.TRAP (TRAP synthetic)
# 			SY.TRF (TRF synthetic)
# 			SY.TSEA (TSEA synthetic)
# 			SY.TTA (TTA synthetic)
# 			SY.UCM (UCM synthetic)
# 			SY.VRDI (VRDI synthetic)
# 			SY.WACK (WACK synthetic)
# 			SY.WAT1 (WAT1 synthetic)
# 			SY.WAT2 (WAT2 synthetic)
# 			SY.WAT3 (WAT3 synthetic)
# 			SY.WAT4 (WAT4 synthetic)
# 			SY.WAT5 (WAT5 synthetic)
# 			SY.WAT6 (WAT6 synthetic)
# 			SY.WAT7 (WAT7 synthetic)
# 			SY.WAX (WAX synthetic)
# 			SY.WAZA (WAZA synthetic)
# 			SY.WRH (WRH synthetic)
# 			SY.YAH (YAH synthetic)
# 			SY.YAN2 (YAN2 synthetic)
# 			TA.H21K (Melozitna River, AK, USA)
# 			TA.H24K (Noodor Dome, AK, USA)
# 			TA.HARP (HAARP, Gakona, AK, USA)
# 			TA.I21K (Tanana, AK, USA)
# 			TA.I23K (Minto, Yukon-Koyukuk, AK, USA)
# 			TA.I26K (Coal Creek Mining Camp, AK, USA)
# 			TA.I29M (Ogilvie Camp, Yukon, CA)
# 			TA.J20K (Nowitna River, AK, USA)
# 			TA.J25K (Salcha River, AK, USA)
# 			TA.J26L (Joseph Creek, AK, USA)
# 			TA.K20K (Telida, AK, USA)
# 			TA.L19K (White Mountain, AK, USA)
# 			TA.L26K (Log Cabin Wilderness Lodge, Tok, AK, USA)
# 			TA.L27K (Beaver Creek, Northway Junction, AK, USA)
# 			TA.M19K (Big River Lodge, Big River, AK, USA)
# 			TA.M20K (Styx River, AK, USA)
# 			TA.M24K (Tolsona, Glennallen, AK, USA)
# 			TA.M26K (Nabesna, AK, USA)
# 			TA.M27K (Edge Creek, AK, USA)
# 			TA.N18K (Kilae Creek, AK, USA)
# 			TA.N19K (Bonanza Creek NPS repeater, AK, USA)
# 			TA.N25K (Chitina, Valdez-Cordova, AK, USA)
# 			TA.O18K (Koktuh Hills, AK, USA)
# 			TA.O19K (Port Alsworth, AK, USA)
# 			TA.O20K (Slope Mountain, AK, USA)
# 			TA.O22K (Cooper Landing, AK, USA)
# 			TA.P18K (Big Mountain, AK, USA)
# 			TA.P19K (Oil Pt, AK, USA)
# 			TA.POKR (Poker Flat Research Range, AK, USA)
# 			TA.Q19K (Cape Douglas, AK, USA)
# 			TA.Q23K (Middleton Island, AK, USA)
# 			TA.TCOL (CIGO, UAF Yankovich Road, Fairbanks, AK, USA)
# 			TA.TOLK (Toolik Lake Research Station, AK, USA)
# 			US.EGAK (Eagle, Central Alaska, Alaska, USA)
# 			XV.F1TN (Tanana River 1, AK, USA)
# 			XV.F2TN (Tanana River 2, AK, USA)
# 			XV.F3TN (Tanana River 3, AK, USA)
# 			XV.F4TN (Tanana River 4, AK, USA)
# 			XV.F5MN (Tanana River 5, Old Minto, AK, USA)
# 			XV.F6TP (Tanana River 6, Topo, AK, USA)
# 			XV.F7TV (Tanana River 7, Tolovana, AK, USA)
# 			XV.F8KN (Tanana River 8, Kantishna, AK, USA)
# 			XV.FAPT (Nenana Airport, AK, USA)
# 			XV.FNN1 (Nunivak 1 well, AK, USA)
# 			XV.FNN2 (Nunivak 2 well, AK, USA)
# 			XV.FPAP (Papi Latham house, AK, USA)
# 			XV.FTGH (Toghotthele, Parks Hwy, AK, USA)
# 		Channels (0):

# %% [markdown]
# ## 2. Retrieve Local and Non-Local Events From The Station

# %% [markdown]
# ### Functions for getting the noise times

# %%
import random
import math
from bisect import bisect
from collections import namedtuple
from typing import List


# Holds a UTCDateTime start and end times of an event
Time = namedtuple('Time', ('start', 'end'))   

def find_closest_index(a, x):
    """
    Find index of rightmost value less than x via binary search
    @param a: Indexable object, the list to look through - MUST BE SORTED
    @param x: Any, the item to find the closest index for in a
    """
    i = bisect(a, x) 
    if i:
        return i
    raise ValueError

def overlaps(time: Time, time2: Time):
    """
    Determines whether two times overlap.
    @returns: boolean, True if the time1 overlaps with time2  
    """
    # Starts after the second time ends, or ends before the second time starts
    return not ((time.start > time2.end) or (time.end < time2.start))

def encompassed(time: Time, sorted_times: List[Time]):
    """
    Determines whether time overlaps with any times in sorted_times
    @param time: Time
    @param sorted_times: sorted list of Time - the list MUST be sorted for this to work
    @return: boolean, True if the time overlaps
    """
    index = find_closest_index(sorted_times, time)
    try:
        left = overlaps(time, sorted_times[index-1])
        curr = overlaps(time, sorted_times[index])
        right = overlaps(time, sorted_times[index+1])
        return any((left, curr, right))
    except IndexError:
        return True     

def get_noise_times(times_to_exclude: List[UTCDateTime], 
                    startafter: UTCDateTime, endbefore: UTCDateTime, amount: int, duration: float):
    """
    Generates a list of noise times, which are not in the times_to_exclude
    @param times_to_exclude: a list of times of events 
    @param startafter: Generate noise windows after this time
    @param endbefore: Generate noise windows before this time
    @param amount: How many noise windows to generate
    @param duration: How long each event in times_to_exclude and noise window should be, to prevent overlapping
    """
    exclude = [Time(time, time + duration) for time in times_to_exclude]
    exclude.sort()
    noise_times = []
    
    def random_time():
        return startafter + random.randint(0, math.floor(endbefore - startafter))
    
    # Generate a random time
    while len(noise_times) < amount:
        rt = random_time()
        rand_time = Time(rt, rt + duration)
                         
        if not encompassed(rand_time, exclude):
            noise_times.append(rt)
            index = bisect(exclude, rand_time)
            exclude = exclude[:index] + [rand_time] + exclude[index:]
        
    return noise_times

# %%
from obspy.clients.fdsn import Client
from obspy.core.event import Catalog


# Types
local_catalog_events: Catalog
nonlocal_catalog_events: Catalog
    

# Code
client = Client(CLIENT_NAME)

# Local Events
local_catalog_events = client.get_events(latitude=station.latitude, 
                                 longitude=station.longitude,
                                 maxradius=MAX_RADIUS,  # Local
                                 starttime=STARTTIME,
                                 limit=NUM_EVENTS,
                                 endtime=ENDTIME
                                 )

# Nonlocal Events
nonlocal_catalog_events = client.get_events(latitude=station.latitude, 
                                 longitude=station.longitude,
                                 minradius=NONLOCAL_MIN_RADIUS,  # Nonlocal
                                 limit=NUM_EVENTS,
                                 starttime=STARTTIME,
                                 endtime=ENDTIME
                                 )

print("LOCAL EVENTS:", len(local_catalog_events))
print("NONLOCAL EVENTS:", len(nonlocal_catalog_events))
# Out:
# LOCAL EVENTS: 2000
# NONLOCAL EVENTS: 2000

# %%
local_catalog = local_catalog_events[:NUM_EVENTS]  
nonlocal_catalog = nonlocal_catalog_events[:NUM_EVENTS]

print("LOCAL EVENTS:", len(local_catalog))
print("NONLOCAL EVENTS:", len(nonlocal_catalog))
# Out:
# LOCAL EVENTS: 2000
# NONLOCAL EVENTS: 2000

# %% [markdown]
# ### Visualize Events Local and NonLocal

# %%
# Plot Local Events
#local_catalog.plot()
#local_catalog.plot(projection="local")

# %%
# Plot Nonlocal Events
# nonlocal_catalog.plot()

# %% [markdown]
# ## 3. Retrieve Waveforms

# %% [markdown]
# ### Get times where events occur

# %%
from obspy.core import Stream
from pprint import pprint


# Functions
def get_event_times(catalog: Catalog) -> List[UTCDateTime]:
    """
    Gets event times from a catalog and returns a list of them.
    """
    return [event.origins[0].time for event in catalog]


# Types
local_times: List[UTCDateTime]
non_local_times: List[UTCDateTime]
noise_times: List[UTCDateTime]
    
    
# Code
catalog_local_times = get_event_times(local_catalog_events)
catalog_nonlocal_times = get_event_times(nonlocal_catalog_events)


# Get times for each category
noise_times = get_noise_times(catalog_local_times + catalog_nonlocal_times, 
                              min(catalog_nonlocal_times), # startafter
                              max(catalog_nonlocal_times), # endbefore
                              NUM_NOISE_EVENTS, 
                              DURATION)

local_times =  get_event_times(local_catalog)
nonlocal_times = get_event_times(nonlocal_catalog)

print("Got times")
# Out:
# Got times

# %% [markdown]
# ### Prepare data for the client

# %%
# Functions
end = lambda start_time: start_time + DURATION

def create_bulk(times):
    return [(network.code, station.code, "*", "HN*", time, end(time)) for time in times]


# Code
local_bulk = create_bulk(local_times)
nonlocal_bulk = create_bulk(nonlocal_times)
noise_bulk = create_bulk(noise_times)
print("Created Bulks")
# Out:
# Created Bulks

# %% [markdown]
# ### Get Waveforms

# %% [markdown]
# #### Need to do a time test to compare the next two cells

# %%
##### The non-async way #####

# Get Waveforms From Server

#waveforms = client.get_waveforms_bulk(bulk) # Can't figure out how to plot this correctly
#waveforms = [client.get_waveforms(*data, attach_response=True) for data in local_bulk]

# print("Got Waveforms")

# %%
import asyncio  
import time
from functools import wraps
from obspy.clients.fdsn.header import FDSNNoDataException


def slide(iterable, num, stagger=None):
    """ 
    A sliding window over an iterator, yielding sub arrays.
    @param iterable: Iterable
    @param num: int, the size of each subarray
    @param stagger: int, the number of elements to start the next subarray by 
    
    Example:
    for arr in slide(list(range(98)), 5):
        print(arr)
    """
    stagger = num - stagger if stagger else 0
    start = 0
    end = num
    
    while start + stagger < len(iterable):
        yield iterable[start:end]
        start = end - stagger
        end += num - stagger
        
        

class AsyncClient(Client):
    
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.loop = asyncio.get_event_loop()
    
    async def async_get_waveforms(self, *args, **kwargs):
        """ 
        Get waveforms asyncronously 
        @param *args, **kwargs: the arguments passed to Client.get_waveforms
        @return: future
        """
        
        # kwargs can't be passed to loop.run_in_executor, so create a wrapper function.
        @wraps(self.get_waveforms)
        def call_with_kwargs(*args):
            return self.get_waveforms(*args, **kwargs)
            
        future = self.loop.run_in_executor(None, call_with_kwargs, *args)
        return await future
    
    def _get_batch(self, batch: List, bulk_kwargs: dict):
        """
        Retrieves a batch of waveforms by calling 'get_waveforms' for each list of args in the batch
        @param batch: list[list],each sublist is arguments to be passed to get_waveforms
        @param bulk_kwargs: keyword arguments to pass the get_waveforms function. Will be applied to every batch.
        """
        tasks = [self.async_get_waveforms(*data, **bulk_kwargs) for data in batch] # List of Asyncio Tasks
        results = self.loop.run_until_complete(asyncio.gather(*tasks))             # Blocks until finished 
        return results
    
    def get_waveforms_bulk(self, bulk: List[List], batch_size=10, separation=1, bulk_kwargs=None, skip_errors=True):
        """
        Gets waveforms in a bulk asynchronously.
        @param bulk: List[List], data to pass get_waveforms like at - https://docs.obspy.org/packages/autogen/obspy.clients.fdsn.client.Client.get_waveforms_bulk.html
        @param batch_size: how many simultaneous requests are sent at one. Keep this number < 10 
        @param bulk_kwargs: dict, kwargs to pass to each get_waveforms request because you can't store them in the bulk list.
        @param skip_errors: boolean, if False raises FSDN error if the server is missing a waveform  
        @return: List[Stream], a list of the waveforms
        """
        if batch_size > 10: raise ValueError("Batch size too high, could overload server.")
            
        waveforms = []
        bulk_kwargs = bulk_kwargs or {}
        
        generate_waveforms = self.yield_waveforms_bulk(bulk, batch_size, separation, bulk_kwargs, skip_errors)
        
        for i, result in enumerate(generate_waveforms):
            waveforms.extend(result)
            print(f"Got batch {i+1}: {len(waveforms)}/{len(bulk)}", end="\r")
        
        print("\nDone.")
        return waveforms
    
    def yield_waveforms_bulk(self, bulk, batch_size=10, separation=1, bulk_kwargs=None, skip_errors=True):
        """
        Yields a list of streams of size batch_size. Each call to the generator makes another call to the server.
        This way you can be more strategic about how you get your data, hold it in memory, etc.
        @yield: List[Stream]
        """
        bulk_kwargs = bulk_kwargs or {}

        if batch_size > 10: 
            raise ValueError("Batch size too high, could overload server.")

        for i, batch in enumerate(slide(bulk, batch_size)): 
            try:
                yield self._get_batch(batch, bulk_kwargs)
                time.sleep(separation)
            except FDSNNoDataException as e:
                if skip_errors:
                    print(f"Skipping batch {i} FDSNNoDataException")
                    continue
                raise e

# %%
# Get Waveforms
import obspy
client = AsyncClient(CLIENT_NAME)

local_waveforms = client.get_waveforms_bulk(local_bulk, 
                                            batch_size=5, 
                                            bulk_kwargs=dict(attach_response=True),
                                            skip_errors=True)


nonlocal_waveforms = client.get_waveforms_bulk(nonlocal_bulk, 
                                               batch_size=5, 
                                               bulk_kwargs=dict(attach_response=True),
                                               skip_errors=True)

noise_waveforms = client.get_waveforms_bulk(noise_bulk, 
                                               batch_size=5, 
                                               bulk_kwargs=dict(attach_response=True),
                                               skip_errors=True)


print("\nRetrieved Local:", len(local_waveforms))
print("\nRetrieved Nonlocal:", len(nonlocal_waveforms))
print("\nRetrieved Noise:", len(noise_waveforms))
# Out:
# Got batch 400: 2000/2000
# Done.
# Got batch 400: 2000/2000
# Done.
# Got batch 400: 2000/2000
# Done.
#
# Retrieved Local: 2000
#
# Retrieved Nonlocal: 2000
#
# Retrieved Noise: 2000

# %% [markdown]
# ## 4. Filter

# %%
def filter_waveforms(waveforms: List[Stream]) -> List[Stream]:
    """ 
    Filters the waveforms (in place) 
    @return: generator -> Stream
    """
    waveforms = map(lambda stream: stream.remove_response().filter('bandpass',  
                                                                   freqmin=MIN_FREQ, 
                                                                   freqmax=MAX_FREQ)\
                                                            .taper(max_percentage=.5), waveforms) 
    return waveforms
    

local_waves = list(filter_waveforms(local_waveforms.copy()))
nonlocal_waves = list(filter_waveforms(nonlocal_waveforms.copy()))
noise_waves = list(filter_waveforms(noise_waveforms.copy())) 
print("Filtered")
# Out:
# Filtered

# %% [markdown]
# ## 5. Write Events to Spectrogram Image

# %% [markdown]
# ### Functions for Writing

# %%
from typing import List
from obspy import Stream
from multiprocessing import Pool
import matplotlib.pyplot as plt
from matplotlib.ticker import NullLocator
import glob
import os

def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)
        
        
def write_waveforms(waveforms: List[Stream], path):
    create_directory(path)
    for i, stream in enumerate(waveforms):
        stream.write(os.path.join(path, f'{i}.mseed'), format="MSEED")
        
        
def write_waveform(stream, file_path):
    print("Writing: ", os.path.basename(file_path), end='\r')
    stream.write(file_path, format="MSEED")
    

def async_write_waveforms(waveforms: List[Stream], path):
    print("Writing Waveforms...")
    create_directory(path)

    work = [] 
    
    # Prep the file paths
    for i, stream in enumerate(waveforms):
        file_path = os.path.join(path, f'{i}.mseed')
        
        # Add the args for each stream
        work.append(
            (stream, file_path)  
        )

    # Run with multiprocess
    pool = Pool()
    pool.starmap(write_waveform, work)
    
    print("\nWrote Waveforms")
    

def remove_borders(path):
    """ 
    Removes borders of all .png files in curr directory  
    Must have ImageMagik installed.
    """
    png_paths = glob.glob(f"{path}/*.png")
    
    for file in png_paths:
        print("Trimming: ", file, end='\r')
        # !convert $file -trim +repage $file;
        

def write_spectrogram(stream, path):
    """
    @param stream: Stream, the file to make a spectrogram from.
                   Each trace should be one component.
    
    @param path: Str, the directory to write into.
    
    Each component of the stream is written as its own figure, a .png file.
    Components eg. "NNE" are saved as the filename eg. "NNE.png".
    """
    create_directory(path)
    figure_list = stream.spectrogram(show=False, title="")
    
    for figure, channel in zip(figure_list, get_channel_names(stream)):
        axes = figure.gca() 
        axes.set_xlim([0, DURATION])
        axes.set_ylim([0, MAX_FREQ])

        # Get Rid of Whitespace
        axes.axis("off")
        axes.xaxis.set_major_locator(NullLocator())
        axes.yaxis.set_major_locator(NullLocator())
        figure.savefig(f"{path}/{channel}.png", bbox_inches='tight', pad_inches=0, transparent=True)
        
        # Free memory
        figure.clf()
        plt.close(figure) 

    remove_borders(path)  # Remove borders of all the spectrograms
    
    

def write_spectrograms(waveforms, path):   
    for i, stream in enumerate(waveforms):
        dir_path = os.path.join(path, str(i))
        create_directory(dir_path)
        write_spectrogram(stream, dir_path)
    

def async_write_spectrograms(waveforms, path):
    """
    @param waveforms: List[Stream], the waveforms to make spectrograms from.
    @param path: str, The directory to write to
    
    1. Calls 'write_spectrogram' on each Stream. 
    2. Each stream is written to its own folder
    3. All components are written to their own file as a spectrogram .png image.
    """
    print("Writing Files...")

    work = []   # Args that will be passed to the write_spectrogram function
    
    # Prep the file paths
    for i, stream in enumerate(waveforms):
        dir_path = os.path.join(path, str(i))
        create_directory(dir_path)
        
        # Add the args for each stream
        work.append(
            (stream, os.path.join(path, str(i)))  # arguments to the 'write_spectrogram' function
        )

    # Run with multiprocess
    pool = Pool()
    pool.starmap(write_spectrogram, work)             # Map the 'write_spectrogram' function to the work
    
    print("\nWrote Files")

# %%
import warnings

# Constants
DIR_PATH = os.path.join(os.getcwd(), f"waveforms/{NAME}")

# Write Waveforms
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    async_write_waveforms(local_waves, os.path.join(DIR_PATH, "local"))   
    async_write_waveforms(nonlocal_waves, os.path.join(DIR_PATH, "non_local"))   
    async_write_waveforms(noise_waves, os.path.join(DIR_PATH, "noise"))   
    
print("Finished Writing")
# Out:
# Writing Waveforms...
#
# Wrote Waveforms
# Writing Waveforms...
#
# Wrote Waveforms
# Writing Waveforms...
#
# Wrote Waveforms
# Finished Writing

# %%
#### READ WAVEFORMS ####

# from obspy import read
# import glob
# import os

# DIR_PATH = os.path.join(os.getcwd(), f"waveforms/{NAME}/noise")
# def read_waveforms(dir_path):
#     files = glob.glob(os.path.join(dir_path, '*.mseed'))
#     waveforms = [read(file) for file in files]
#     return waveforms

# noise_waves = read_waveforms(DIR_PATH)

# %%
# Constants
DIR_PATH = os.path.join(os.getcwd(), f"spectrograms/{NAME}")

# Write Waveforms
async_write_spectrograms(local_waves, os.path.join(DIR_PATH, "local"))   
async_write_spectrograms(nonlocal_waves, os.path.join(DIR_PATH, "non_local"))   
async_write_spectrograms(noise_waves, os.path.join(DIR_PATH, "noise"))
# Out:
# Writing Files...
# Trimming:  /data/pytorch_earthquake_recognition/spectrograms/CaliforniaQuakes/local/573/HNN.png

# %% [markdown]
# # Tests

# %%
import unittest 

class TestMethods(unittest.TestCase):
 

    def test_overlaps(self):
        time1 = UTCDateTime(2015, 1, 1, 10, 0, 10)
        time2 = UTCDateTime(2015, 1, 1, 10, 0, 19)
        time3 = UTCDateTime(2015, 1, 1, 10, 0, 30)
        t1 = Time(time1, time1 + 10)
        t2 = Time(time2, time2 + 10)
        t3 = Time(time3, time3 + 10)
        self.assertTrue(overlaps(t1, t2))
        self.assertFalse(overlaps(t2, t3))

        
    def test_encompassed(self):
        t = UTCDateTime(2015, 1, 1, 10, 0, 0) 
        times = [Time(t + 10*i, t + 10*(i+1)) for i in range(1, 7)]  # 1 minute of times 
        times.append(Time(t+1000, t+1010))
        times.append(Time(t+1010, t+1020))
        times.sort()                           # sorted just to remember that the function requires sorted times
        
        
        # Encompassed within the times
        self.assertTrue(encompassed(Time(t+30, t+40), times))
        
        # Not encompassed
        self.assertFalse(encompassed(Time(t+990, t+999), times))
        
        # Value should be within the range of times... otherwise it is invalid.
        # This is because we only have knowledge of events between the start and end time
        # we can't generate noise times outside this range.
        with self.assertRaises(ValueError):
            encompassed(Time(t-10, t), times) 
            
            
    def test_find_closest_index(self):
        lst = [1, 2, 3, 5, 6]
        self.assertEqual(find_closest_index(lst, 2), 2)  # defaults to finding index to the right  
        self.assertEqual(find_closest_index(lst, 4), 3) 
        
        with self.assertRaises(ValueError):
            find_closest_index(lst, 0)
            
            
            
    def test_get_noise_times(self):
        t = UTCDateTime(2015, 1, 1, 10, 0, 0) 
        exclude = [t + 60*i for i in range(1, 11)]  # 10 times in a 10 minute range 
    
        times = get_noise_times(exclude, startafter=exclude[0], endbefore=exclude[-1], amount=10, duration=10)
        
        
        # Make sure none of the noise times overlap with the event (exclude) times
        exclude_times = [Time(time, time+10) for time in exclude]
        self.assertFalse(any((encompassed(Time(time, time+10), exclude_times)) for time in times))
        
        # Make sure that the times are generated in the correct time window
        times.sort()
        self.assertTrue((times[0] > exclude[0]) and (times[-1] < exclude[-1]))
        
        # Should generate the correct amount
        self.assertEqual(len(times), 10)
        
        
    def test_slide(self):
        gen = slide(list(range(7)), 3)
        self.assertEqual(next(gen), [0, 1, 2])
        self.assertEqual(next(gen), [3, 4, 5])
        self.assertEqual(next(gen), [6])
        
        res = list(slide(list(range(7)), 3, 2))
        self.assertEqual(res, [[0, 1, 2], [2, 3, 4], [4, 5, 6]])

# %%
methods = TestMethods()

suite = unittest.TestLoader().loadTestsFromModule(methods)
unittest.TextTestRunner().run(suite)
