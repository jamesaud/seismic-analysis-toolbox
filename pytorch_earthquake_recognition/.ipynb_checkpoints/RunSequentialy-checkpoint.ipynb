# %%
import os

# %%
names = [
    'Amatrice',
    'Oklahoma',
    'SouthAmerica',
    'California',
    'Alaska',
    'Costa',
    'Puerto'
]

# %%
for name in names:
    with open('event_name.txt', 'w') as file:
        file.write(name)
    # %run retrieve_data.ipynb
# Out:
# Costa
