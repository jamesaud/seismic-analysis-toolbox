# %%
import os

# %%
names = [
    'Amatrice',
    'Oklahoma',
    'SouthAmerica',
    'California',
    'Costa',
    'Puerto',
    'Alaska'
    ]

# %%
for name in names:
    with open('event_name.txt', 'w') as file:
        file.write(name)
    # %run retrieve_data.ipynb
    print('-' * 50, "FINISHED " + name, '-' * 50)
# Out:
# LOCAL EVENTS: 1249
# NONLOCAL EVENTS: 10
# NOISE EVENTS to Exclude: 1735
# Got times
# Created Bulks
# Skipping batch 0 FDSNNoDataException
# Skipping batch 2 FDSNNoDataException
# Skipping batch 12 FDSNNoDataException
# Skipping batch 55 FDSNNoDataException
# Skipping batch 60 FDSNNoDataException
# Skipping batch 61 FDSNNoDataException
# Skipping batch 84 FDSNNoDataException
# Skipping batch 135 FDSNNoDataException
# Skipping batch 140 FDSNNoDataException
# FDSN Exception:  Unknown Error (timeout): timed out
# Skipping batch 233 FDSNNoDataException
# Skipping batch 234 FDSNNoDataException
# Got batch 238: 1189/1249
# Done.
#
# Retrieved Local: 1189
# Got batch 2: 8/8
# Done.
#
# Retrieved Nonlocal: 8
# Skipping batch 4 FDSNNoDataException
# Skipping batch 22 FDSNNoDataException
# Skipping batch 23 FDSNNoDataException
# Skipping batch 43 FDSNNoDataException
# Skipping batch 45 FDSNNoDataException
# Skipping batch 55 FDSNNoDataException
# Skipping batch 74 FDSNNoDataException
# ...
