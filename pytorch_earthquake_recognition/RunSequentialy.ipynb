# %%
import os

# %%
names = [
    # 'Amatrice',
    'Oklahoma',
    'SouthAmerica',
    'California',
    'Costa',
    'Puerto',
    'Alaska'
    ]

# %%
for name in names:
    with open('event_name.txt', 'w') as file:
        file.write(name)
    # %run retrieve_data.ipynb
    print('-' * 50, "FINISHED " + name, '-' * 50)
# Out:
# LOCAL EVENTS: 2000
# NONLOCAL EVENTS: 10
# NOISE EVENTS to Exclude: 790
# Got times
# Created Bulks
# Skipping batch 175 FDSNNoDataException
# Skipping batch 176 FDSNNoDataException
# Skipping batch 220 FDSNNoDataException
# Skipping batch 258 FDSNNoDataException
# Got batch 396: 1980/2000
# Done.
#
# Retrieved Local: 1980
# Got batch 2: 7/7
# Done.
#
# Retrieved Nonlocal: 7
# Skipping batch 107 FDSNNoDataException
# Got batch 799: 3995/4000
# Done.
#
# Retrieved Noise: 3995
# Writing Waveforms...
#
# Wrote Waveforms
# Writing Waveforms...
#
# Wrote Waveforms
# Writing Waveforms...
#
# Wrote Waveforms
# Finished Writing
# Filtered
# Writing Files...
# Trimming:  /data/pytorch_earthquake_recognition/spectrograms/OklahomaQuakes/local/24/HNZ.pngg
