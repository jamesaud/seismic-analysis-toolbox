# %%
import os

# %%
names = [
#     'Amatrice',
#     'Oklahoma',
#     'SouthAmerica',
#     'California',
     'Costa',
#      'Puerto',
#     'Alaska'
    ]

# %%
for name in names:
    with open('event_name.txt', 'w') as file:
        file.write(name)
    # %run retrieve_data.ipynb
    print('-' * 50, "FINISHED " + name, '-' * 50)
# Out:
# LOCAL EVENTS: 1753
# NONLOCAL EVENTS: 10
# NOISE EVENTS to Exclude: 1735
# Got times
# Created Bulks
# Skipping batch 0 FDSNNoDataException
# Skipping batch 5 FDSNNoDataException
# Skipping batch 6 FDSNNoDataException
# Skipping batch 25 FDSNNoDataException
# Skipping batch 28 FDSNNoDataException
# Skipping batch 95 FDSNNoDataException
# Skipping batch 101 FDSNNoDataException
# Skipping batch 102 FDSNNoDataException
# Skipping batch 132 FDSNNoDataException
# Skipping batch 205 FDSNNoDataException
# Skipping batch 213 FDSNNoDataException
# Skipping batch 214 FDSNNoDataException
# Skipping batch 331 FDSNNoDataException
# Skipping batch 332 FDSNNoDataException
# Got batch 337: 1683/1753
# Done.
#
# Retrieved Local: 1683
# Got batch 2: 9/9
# Done.
#
# Retrieved Nonlocal: 9
# Skipping batch 8 FDSNNoDataException
# Skipping batch 13 FDSNNoDataException
# Skipping batch 22 FDSNNoDataException
# Skipping batch 24 FDSNNoDataException
# Skipping batch 29 FDSNNoDataException
# ...
