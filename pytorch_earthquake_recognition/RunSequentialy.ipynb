# %%
import os

# %%
names = [
    'Amatrice',
    'Oklahoma',
    'SouthAmerica',
    'California',
    'Alaska',
    'Costa',
    'Puerto'
    ]

# %%
for name in names:
    with open('event_name.txt', 'w') as file:
        file.write(name)
    # %run retrieve_data.ipynb
# Out:
# Getting quakes for Amatrice
# ---------------------------------------------------------------------------
# FDSNNoDataException                       Traceback (most recent call last)
# /data/pytorch_earthquake_recognition/retrieve_data.ipynb in <module>()
#      25                                  limit=NUM_EVENTS,
#      26                                  starttime=STARTTIME,
# ---> 27                                  endtime=ENDTIME
#      28                                  )
#      29
#
# /opt/conda/lib/python3.6/site-packages/obspy/clients/fdsn/client.py in get_events(self, starttime, endtime, minlatitude, maxlatitude, minlongitude, maxlongitude, latitude, longitude, minradius, maxradius, mindepth, maxdepth, minmagnitude, maxmagnitude, magnitudetype, includeallorigins, includeallmagnitudes, includearrivals, eventid, limit, offset, orderby, catalog, contributor, updatedafter, filename, **kwargs)
#     511             "event", DEFAULT_PARAMETERS['event'], kwargs)
#     512
# ...
